# %%
import pytesseract
from PIL import Image
import time
import os
import jiwer
import numpy as np

# %%
test_dir = r'..\dataset\data\prepared\test'
cers=[]
wers=[]

# %% [markdown]
# ### Loop through test dataset folder and run pytesseract

# %%
def eval_ocr(model):
    for filename in os.listdir(test_dir):
        if filename.endswith('.png'):
            image_path = os.path.join(test_dir, filename)
            gt_file = os.path.splitext(filename)[0] + '.gt.txt'
            gt_path = os.path.join(test_dir, gt_file)
            if os.path.exists(gt_path):
                with open(gt_path, 'r', encoding='utf-8') as f:
                    gt = f.read()
                    image = Image.open(image_path)
                    text = pytesseract.image_to_string(image,lang=model)
                    print(f'Ground Truth: {gt}')
                    print(f'OCR Text: {text}')
                    cer = jiwer.wer(gt, text)
                    wer = jiwer.wer(gt, text)
                    cers.append(cer)
                    wers.append(wer)
                    print(f'Image: {filename}, CER: {cer}, WER: {wer}')
    average_cer = np.mean(cers)
    average_wer = np.mean(wers)
    print(f"Average CER: {average_cer:.2f}\n Average WER: {average_wer:.2f}")

# %% [markdown]
# #### Case I: No Tuning

# %%
eval_ocr('nep') ## nep is the default tesseract model for nepali
# Out:
# Ground Truth: बबरमहल
#
# OCR Text: बबरमहल,
#
# Image: 102.png, CER: 1.0, WER: 1.0
# Ground Truth: मितिः २०८९/०४/१३
#
# OCR Text: मितिः २०८९/०४/१३
#
# Image: 107.png, CER: 0.0, WER: 0.0
# Ground Truth: बल्खु, काठमाडौँ।
# OCR Text:
# Image: 113.png, CER: 1.0, WER: 1.0
# Ground Truth: त्रिभुवन विश्वविद्यालय
# OCR Text: त्रिभुवन विश्वविद्यालय
#
# Image: 121.png, CER: 0.0, WER: 0.0
# Ground Truth: ङ.) परीक्षाको लागि चाहिने लगवुक, ग्राफ
#
# OCR Text: डड.) परीक्षाको लागि चाहिने लगवुक, ग्राफ
#
# Image: 126.png, CER: 0.16666666666666666, WER: 0.16666666666666666
# Ground Truth: विषय प्रथम वर्ष
#
# OCR Text: विषय प्रथम वर्षे
#
# Image: 129.png, CER: 0.3333333333333333, WER: 0.3333333333333333
# Ground Truth: विज्ञप्ति
#
# OCR Text: विज्ञप्ति
#
# Image: 137.png, CER: 0.0, WER: 0.0
# Ground Truth: नोट : उपरोक्त अनुसार अभिलेख
#
# OCR Text: | नोट : उपरोक्त अनुसार अभिलेख
#
# Image: 146.png, CER: 0.2, WER: 0.2
# Ground Truth: परीक्षा केन्द्र : पछि तोकिने छ।
#
# OCR Text: परीक्षा केन्द्र : पछि तोकिने छ।
#
# Image: 154.png, CER: 0.0, WER: 0.0
# Ground Truth: द्वष्टव्य :क) उपरोक्त परीक्षा तालिको अनुसार
#
# OCR Text: द्वष्टव्य :क) उपरोक्त परीक्षा तालिको अनुसार
#
# Image: 155.png, CER: 0.0, WER: 0.0
# Ground Truth: सहायक डिन
#
# OCR Text: सहायक डन ।
#
# Image: 160.png, CER: 1.0, WER: 1.0
# Ground Truth: श्री ५ को सरकार
#
# OCR Text: श्री प को सरकार
#
# Image: 173.png, CER: 0.25, WER: 0.25
# Ground Truth: प्रकाशित गरिएको छ ।
#
# OCR Text: प्रकाशित गरिएको छ ।
#
# Image: 178.png, CER: 0.0, WER: 0.0
# Ground Truth: समूद्रपारतिर निर्यात बढ्दैछ र राष्ट्र बैङ्कको
#
# OCR Text: समूद्रपारतिर निर्यात बढ्दैछ र राष्ट्र बैङ्कको
#
# Image: 182.png, CER: 0.0, WER: 0.0
# Ground Truth: जम्मा रू. ५९ करोड ८७ लाखको
# OCR Text: जम्मा रू. ५९ करोड ८७ लाखको
#
# Image: 186.png, CER: 0.0, WER: 0.0
# Ground Truth: २:०० देखि ३:०० बजेको बीचमा
#
# OCR Text: २:०० देखि ३:०० बजेको बीचमा
#
# Image: 191.png, CER: 0.0, WER: 0.0
# Ground Truth: चलानी नं. :
#
# OCR Text: चलानी नं. ;
#
# Image: 199.png, CER: 0.3333333333333333, WER: 0.3333333333333333
# Ground Truth: २०६७
# OCR Text:
# Image: 204.png, CER: 1.0, WER: 1.0
# Ground Truth: नेपाल सरकार
# OCR Text:
# Image: 205.png, CER: 1.0, WER: 1.0
# Ground Truth: राष्ट्रिय सिमसार नीति
#
# OCR Text: राष्ट्रिय सिमसार नीति
#
# Image: 209.png, CER: 0.0, WER: 0.0
# Ground Truth:  अनुगमन : ४२११७४२
#
# OCR Text: || अनुगमन : ८४२११७४२
#
# Image: 217.png, CER: 0.6666666666666666, WER: 0.6666666666666666
# Ground Truth: कीर्तिपुर, काठमाडौँ, नेपाल
# OCR Text:
# Image: 227.png, CER: 1.0, WER: 1.0
# Ground Truth: अन्य* ८%
#
# OCR Text: अन्य
#
# Image: 233.png, CER: 1.0, WER: 1.0
# Ground Truth: सभामुख महोदय,
#
# OCR Text: सभामुख महोदय,
#
# Image: 245.png, CER: 0.0, WER: 0.0
# Ground Truth: प्र. मन्त्रालय राज्यव्यवस्थाको सूचना
#
# OCR Text: प्र, मन्त्रालय राज्यव्यदस्थाको सूचना
#
# Image: 250.png, CER: 0.5, WER: 0.5
# Ground Truth: यो सालमा ३६ वर्ष नोकरी पुगेकालाई जानपद
#
# OCR Text: यो सालमा
#
# Image: 254.png, CER: 0.7142857142857143, WER: 0.7142857142857143
# Ground Truth: डेपुटी डाइरेक्टर श्री कृष्णबहादुर राजबाहक - - १
#
# OCR Text: डेपुटी डाइरेक्टर श्री कृष्णबहादुर राजबाहक --
#
# Image: 257.png, CER: 0.375, WER: 0.375
# Ground Truth: प्रमुख सेक्रे टरी श्री . बृ. ज. चन्द्रबहादुर थापा - - १
# OCR Text: प्रमुख सत्र टरी थी उ. ज. चन्द्रबहादुर थापा --
#
# Image: 260.png, CER: 0.5833333333333334, WER: 0.5833333333333334
# Ground Truth: लिलाम बिक्री सम्बन्धी १५ दिने गोप्य शिलबन्दी
#
# OCR Text: लिलाम बित्रही सम्बल्धी १५ दिने गोप्य शिलबन्दी
#
# Image: 262.png, CER: 0.2857142857142857, WER: 0.2857142857142857
# Ground Truth: ५. आदिवासी जनजाति आयोग गठन गर्ने ।
#
# OCR Text: ५. आदिवासी जनजाति आयोग गठन गर्ने ।
#
# Image: 27.png, CER: 0.0, WER: 0.0
# Ground Truth: (ख) सुदुर पश्चिम प्रदेशको गेटामा सरकारी मेडिकल कलेज स्थापना
#
# OCR Text: (ख) सदर पश्चिम प्रदेशको गेटामा सरकारी मेडिकल कलेज स्थापना
#
# Image: 33.png, CER: 0.1111111111111111, WER: 0.1111111111111111
# Ground Truth: नाम: टेक बहादुर शाह
#
# OCR Text: जाम: टेक बहादुर शाह.
#
# Image: 50.png, CER: 0.5, WER: 0.5
# Ground Truth: मिति २०७९ चैत्र १८ गते शनिबार सरकारी वार्ता
#
# OCR Text: मिति २०७९ चैत्र १८ गते शनिबार सरकारी वार्ता
#
# Image: 57.png, CER: 0.0, WER: 0.0
# Ground Truth: उपसचिव श्री उमाकान्त अधिकारी - सदस्य
#
# OCR Text: नै” उपसचिव श्री उमाकान्त अधिकारी -सदस्य
#
# Image: 65.png, CER: 0.5, WER: 0.5
# Ground Truth: नेकपा (माओवादी केन्द्र)
#
# OCR Text: नेकपा (माओवादी केन्द्र)
#
# Image: 76.png, CER: 0.0, WER: 0.0
# Ground Truth: काठमाडौं, नेपाल ।
#
# OCR Text: काठमाडौं नेपाल ।
#
# Image: 88.png, CER: 0.3333333333333333, WER: 0.3333333333333333
# Ground Truth: घ) पाटन संयुक्त क्यामपस, पाटनढोका केन्द्र
# OCR Text: घ) पाटन संयुक्त क्याम्पस, पाटनढोका केन्द्र
#
# Image: 9.png, CER: 0.16666666666666666, WER: 0.16666666666666666
# Average CER: 0.35
#  Average WER: 0.35

# %% [markdown]
# ### Case II: Fine Tuned on 229 lined dataset

# %%
eval_ocr('nep-new') ## nep-new is the fine tuned model stored in tessdata folder
# Out:
# Ground Truth: बबरमहल
#
# OCR Text:
# Image: 102.png, CER: 1.0, WER: 1.0
# Ground Truth: मितिः २०८९/०४/१३
#
# OCR Text: मितिः २०८९/०४/१३
#
# Image: 107.png, CER: 0.0, WER: 0.0
# Ground Truth: बल्खु, काठमाडौँ।
# OCR Text:
# Image: 113.png, CER: 1.0, WER: 1.0
# Ground Truth: त्रिभुवन विश्वविद्यालय
# OCR Text:
# Image: 121.png, CER: 1.0, WER: 1.0
# Ground Truth: ङ.) परीक्षाको लागि चाहिने लगवुक, ग्राफ
#
# OCR Text:
# Image: 126.png, CER: 1.0, WER: 1.0
# Ground Truth: विषय प्रथम वर्ष
#
# OCR Text: विषय प्रथम वर्ष
#
# Image: 129.png, CER: 0.0, WER: 0.0
# Ground Truth: विज्ञप्ति
#
# OCR Text:
# Image: 137.png, CER: 1.0, WER: 1.0
# Ground Truth: नोट : उपरोक्त अनुसार अभिलेख
#
# OCR Text:
# Image: 146.png, CER: 1.0, WER: 1.0
# Ground Truth: परीक्षा केन्द्र : पछि तोकिने छ।
#
# OCR Text: केन्द्र. पछि तोकिने छ ।
#
# Image: 154.png, CER: 0.8333333333333334, WER: 0.8333333333333334
# Ground Truth: द्वष्टव्य :क) उपरोक्त परीक्षा तालिको अनुसार
#
# OCR Text: द्वष्टव्य :क) उपरोक्त परीक्षा तालिको अनुसार
#
# Image: 155.png, CER: 0.0, WER: 0.0
# Ground Truth: सहायक डिन
#
# OCR Text: सहायक डान
#
# Image: 160.png, CER: 0.5, WER: 0.5
# Ground Truth: श्री ५ को सरकार
#
# OCR Text: श्री ए को सरकार
#
# Image: 173.png, CER: 0.25, WER: 0.25
# Ground Truth: प्रकाशित गरिएको छ ।
#
# OCR Text: प्रकाशित गरिएको छ ।
#
# Image: 178.png, CER: 0.0, WER: 0.0
# Ground Truth: समूद्रपारतिर निर्यात बढ्दैछ र राष्ट्र बैङ्कको
#
# OCR Text:
# Image: 182.png, CER: 1.0, WER: 1.0
# Ground Truth: जम्मा रू. ५९ करोड ८७ लाखको
# OCR Text: जम्मा रू. ५९ करोड ८७ लाखको
#
# Image: 186.png, CER: 0.0, WER: 0.0
# Ground Truth: २:०० देखि ३:०० बजेको बीचमा
#
# OCR Text: २:०० देखि ३:०० बजेको बीचमा
#
# Image: 191.png, CER: 0.0, WER: 0.0
# Ground Truth: चलानी नं. :
#
# OCR Text: चलानी नं. :
#
# Image: 199.png, CER: 0.0, WER: 0.0
# Ground Truth: २०६७
# OCR Text:
# Image: 204.png, CER: 1.0, WER: 1.0
# Ground Truth: नेपाल सरकार
# OCR Text:
# Image: 205.png, CER: 1.0, WER: 1.0
# Ground Truth: राष्ट्रिय सिमसार नीति
#
# OCR Text: राष्ट्रिय समसार नीति
#
# Image: 209.png, CER: 0.3333333333333333, WER: 0.3333333333333333
# Ground Truth:  अनुगमन : ४२११७४२
#
# OCR Text: अनुगमन : ४२११७४२
#
# Image: 217.png, CER: 0.0, WER: 0.0
# Ground Truth: कीर्तिपुर, काठमाडौँ, नेपाल
# OCR Text:
# Image: 227.png, CER: 1.0, WER: 1.0
# Ground Truth: अन्य* ८%
#
# OCR Text:
# Image: 233.png, CER: 1.0, WER: 1.0
# Ground Truth: सभामुख महोदय,
#
# OCR Text:
# Image: 245.png, CER: 1.0, WER: 1.0
# Ground Truth: प्र. मन्त्रालय राज्यव्यवस्थाको सूचना
#
# OCR Text: प्र. मन्त्रालय राज्यव्यवस्थाको सूचना
#
# Image: 250.png, CER: 0.0, WER: 0.0
# Ground Truth: यो सालमा ३६ वर्ष नोकरी पुगेकालाई जानपद
#
# OCR Text: यो सालमा ३६ वर्ष नोकरी पुगेकालाई जानपदै
#
# Image: 254.png, CER: 0.14285714285714285, WER: 0.14285714285714285
# Ground Truth: डेपुटी डाइरेक्टर श्री कृष्णबहादुर राजबाहक - - १
#
# OCR Text: डेपुटी डाइरेक्टर श्री कृष्णबहादुर राजबाहक --
#
# Image: 257.png, CER: 0.375, WER: 0.375
# Ground Truth: प्रमुख सेक्रे टरी श्री . बृ. ज. चन्द्रबहादुर थापा - - १
# OCR Text: प्रमुख सेक्रे टरी श्री बृ. ज. चन्द्रबहादुर थापा -
#
# Image: 260.png, CER: 0.25, WER: 0.25
# Ground Truth: लिलाम बिक्री सम्बन्धी १५ दिने गोप्य शिलबन्दी
#
# OCR Text: लिलाम बित्री सम्बन्धी १५ दिने गोप्य शिलबन्दी
#
# Image: 262.png, CER: 0.14285714285714285, WER: 0.14285714285714285
# Ground Truth: ५. आदिवासी जनजाति आयोग गठन गर्ने ।
#
# OCR Text: ५. आदिवासी जनजाति आयोग गठन गर्ने ।
#
# Image: 27.png, CER: 0.0, WER: 0.0
# Ground Truth: (ख) सुदुर पश्चिम प्रदेशको गेटामा सरकारी मेडिकल कलेज स्थापना
#
# OCR Text: (ख) सुदुर पश्चिम प्रदेशको गेटामा सरकारी मेडिकल कलेज स्थापना
#
# Image: 33.png, CER: 0.0, WER: 0.0
# Ground Truth: नाम: टेक बहादुर शाह
#
# OCR Text: माम: टेक बहादुर शाह
#
# Image: 50.png, CER: 0.25, WER: 0.25
# Ground Truth: मिति २०७९ चैत्र १८ गते शनिबार सरकारी वार्ता
#
# OCR Text: मिति २०७९ चैत्र १८ गते शनिबार सरकारी वार्ता
#
# Image: 57.png, CER: 0.0, WER: 0.0
# Ground Truth: उपसचिव श्री उमाकान्त अधिकारी - सदस्य
#
# OCR Text:
# Image: 65.png, CER: 1.0, WER: 1.0
# Ground Truth: नेकपा (माओवादी केन्द्र)
#
# OCR Text:
# Image: 76.png, CER: 1.0, WER: 1.0
# Ground Truth: काठमाडौं, नेपाल ।
#
# OCR Text: काठमाडौ नेपाल ।
#
# Image: 88.png, CER: 0.3333333333333333, WER: 0.3333333333333333
# Ground Truth: घ) पाटन संयुक्त क्यामपस, पाटनढोका केन्द्र
# OCR Text: घ) पाटन संयुक्त क्याम्पस, पाटनढोका केन्द्र
#
# Image: 9.png, CER: 0.16666666666666666, WER: 0.16666666666666666
# Average CER: 0.41
#  Average WER: 0.41
